# %% [markdown]
# <a href="https://colab.research.google.com/github/yovngburgos/examenEstadistica/blob/main/Laboratorio_7_Probabilidades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidades

# %% [markdown]
# ## Objetivos:

# %% [markdown]
# Aplicar el enfoque frecuentista para calcular probabilidades simples, conjuntas y condicionales para apoyar la toma de decisiones. Utilizando Python como herramienta de apoyo.

# %% [markdown]
# *Nota: Este laboratorio está diseñado para desarrollar razonamiento estadístico. Evita el uso de herramientas de IA para responder las preguntas a menos que esto sea explícitamente sugerido* 🤖. *En su lugar, enfócate en aplicar los conceptos revisados.*

# %% [markdown]
# ## Actividad 1

# %% [markdown]
# 1. Clasifica cada uno de los siguientes experimentos como Aleatorio o Determinista.
#
# | Experimento | Suceso | Clasificación |
# |-------------|--------|----------------|
# | Jugar un boleto en un juego de lotería | Ganar algún premio en la lotería | **Doble click** |
# | Calcular un ángulo interior de un cuadrado cualquiera | El ángulo es recto |**Doble click** |
# | Determinar la cantidad de lluvia que caerá la próxima vez que llueva | Caen entre 20 y 50 mm de agua | **Doble click**|
# | Calcular el número de días que tiene el mes de diciembre | Tiene 31 días |**Doble click** |
# | Determinar el país del equipo ganador en el próximo campeonato mundial | El país es Chile |**Doble click** |
# | Lanzar un dado de seis caras | El resultado es 6 |**Doble click** |

# %% [markdown]
# 2. La siguiente tabla resume el tipo de parentesco con el(la) jefe de hogar obtenido en la Encuesta Nacional de Empleo (ENE), realizada el año 2018 entre los meses de septiembre a noviembre.

# %% [markdown]
# <center>
#
# | Parentesco            | Frecuencia |
# | ----------------------|:----------:|
# | Conviviente           | 49         |
# | Cónyuge               | 141        |
# | Hermano(a) o Cuñado(a)| 16         |
# | Hijo(a) o Hijastro(a) | 347        |
# | Jefe(a) de Hogar      | 335        |
# | Nieto(a)              | 75         |
# | No Pariente           | 4          |
# | Otro Pariente         | 18         |
# | Padres o Suegros      | 16         |
# | Yerno o Nuera         | 11         |
# | **Total General**     | **1012**   |

# %% [markdown]
# Si se le preguntase a cualquiera de las personas ya encuestadas su parentesco con el(la) jefe(a) de hogar, ¿cuál sería el resultado más probable? ¿Y el menos probable? Justifique su respuesta.

# %%
round(347/1012*100,2)
# Out:
# 34.29

# %%
round(4/1012*100,2)
# Out:
# 0.4

# %% [markdown]
# El resultado más probable es hijo(a) o hijastro(a) porque tiene mayor frecuencia. De hecho, su probabilidad es 34,29%.
#
# Por otro lado, el menos probable es no pariente, porque tiene menor frecuencia. En este caso, su probabilidad es de 0,4%

# %% [markdown]
# ## Actividad 2

# %% [markdown]
# El Instituto de Seguridad Laboral recopiló información sobre los accidentes laborales fatales ocurridos en Chile entre los años 2007 y 2016, clasificándolos por grupo etario, género y región donde ocurrieron. La **<a href="https://docs.google.com/spreadsheets/d/1HBf8V23teQNaeaGkWksi0d-HxZGohUgO/export?format=xlsx
# ">base de datos</a>** de esta actividad incluye un registro por cada accidente reportado.

# %%
import pandas as pd
base_datos = pd.read_excel('Base7_2.xlsx')

# %%
base_datos.head(5)
# Out:
#    ID                        REGION    GRUPO  GENERO
# 0   1  Región de Arica y Parinacota  35 a 39  Hombre
# 1   2            Región de Tarapacá  20 a 24  Hombre
# 2   3            Región de Tarapacá  20 a 24  Hombre
# 3   4            Región de Tarapacá  20 a 24  Hombre
# 4   5            Región de Tarapacá  25 a 29  Hombre

# %% [markdown]
# 1. Construye una tabla de frecuencias absolutas que muestre la cantidad total de accidentes fatales, por grupo de edad y género. Luego, responde las siguientes preguntas utilizando la fórmula:
#
# $$P(A) = \frac{Casos \ favorables}{Casos \ totales}$$

# %%
Tabla1 = pd.crosstab( base_datos['GRUPO'], base_datos['GENERO'],
                     margins= True)
Tabla1
# Out:
# GENERO   Hombre  Mujer  All
# GRUPO
# 15 a 19       9      1   10
# 20 a 24      33      0   33
# 25 a 29      49      4   53
# 30 a 34      42      1   43
# 35 a 39      67      5   72
# 40 a 44      53      9   62
# 45 a 49      61      2   63
# 50 a 54      47      3   50
# 55 a 59      27      5   32
# 60 a 64      28      0   28
# 65 a 69      15      0   15
# 70 a 74       4      1    5
# 75 a 79       5      0    5
# All         440     31  471

# %% [markdown]
# 2. Al seleccionar un registro al azar, ¿cuál es la probabilidad de que corresponda a una mujer? ¿Y de que corresponda a un hombre? ¿Cómo se podría explicar esta diferencia?

# %%
#Mujer:
round(31/471*100,1)
# Out:
# 6.6

# %% [markdown]
# **Respuesta:** La probabilidad de escoger al azar un registro de una mujer es 6,6%

# %%
#Hombre:
round(440/471*100,1)
# Out:
# 93.4

# %% [markdown]
# **Respuesta:** La probabilidad de escoger al azar un registro de un hombre es 93,4%

# %% [markdown]
# 3.  Si se escoge el registro de un accidente al azar, ¿cuál es la probabilidad que sea el de:
#
# $\hspace{1.5cm}$ a)  una persona de entre 40 y 49 años?
#
# $\hspace{1.5cm}$ b) una persona de a lo más 34 años?
#
# $\hspace{1.5cm}$ c) un hombre de al menos 40 años?
#
# $\hspace{1.5cm}$ d) una mujer de 70 años o más?

# %%
#a)
round(125/471*100,1)
# Out:
# 26.5

# %% [markdown]
# **Respuesta:** La probabilidad es 26,5%

# %%
#b) Cantidad de personas de a lo más 34 años
10+33+53+43
# Out:
# 139

# %%
#b)
round(139/471*100,1)
# Out:
# 29.5

# %% [markdown]
# **Respuesta:** La probabilidad es 29,5%

# %%
#c) Cantidad de hombres de al menos 40 años
53+61+47+27+28+15+4+5
# Out:
# 240

# %%
#c)
round(240/471*100,1)
# Out:
# 51.0

# %% [markdown]
# **Respuesta:** La probabilidad es 51%

# %%
#d) Cantidad de mujeres mayores a 70
1+0
# Out:
# 1

# %%
round(1/471*100,1)
# Out:
# 0.2

# %% [markdown]
# **Respuesta:** La probabilidad es 0,2%

# %%
#Tabla bivariada con porcentajes:
# Tabla bivariada frecuencia relativa
Tabla = pd.crosstab(base_datos['GRUPO'], base_datos['GENERO'],
                     normalize='all', margins= True)*100
round(Tabla, 1)
# Out:
# GENERO   Hombre  Mujer    All
# GRUPO
# 15 a 19     1.9    0.2    2.1
# 20 a 24     7.0    0.0    7.0
# 25 a 29    10.4    0.8   11.3
# 30 a 34     8.9    0.2    9.1
# 35 a 39    14.2    1.1   15.3
# 40 a 44    11.3    1.9   13.2
# 45 a 49    13.0    0.4   13.4
# 50 a 54    10.0    0.6   10.6
# 55 a 59     5.7    1.1    6.8
# 60 a 64     5.9    0.0    5.9
# 65 a 69     3.2    0.0    3.2
# 70 a 74     0.8    0.2    1.1
# 75 a 79     1.1    0.0    1.1
# All        93.4    6.6  100.0

# %% [markdown]
# 4. Si se escoge aleatoriamente el registro de un accidente y este resulta ser de una mujer, ¿cuál es la probabilidad que sea del grupo de 35 a 39 años?

# %% [markdown]
# En este caso estamos en presencia de una probabilidad condicional. En este caso y sabiendo que el registro es de una mujer, nuestros casos totales se reducen a 31 (cantidad de mujeres en la muestra)

# %%
# casos favorables: 5
# Casos totales: 31 (total mujeres)
round(5/31*100,1)
# Out:
# 16.1

# %% [markdown]
# **Respuesta:** La probabilidad de escoger un registro de entre 35 a 39 años, sabiendo que es mujer, es 16,1%

# %% [markdown]
# 5. Si se escoge aleatoriamente el registro de un accidente y este resulta ser de un hombre, ¿cuál es la probabilidad que tenga 55 años o más?

# %%
#Cantidad de hombres mayores a 55 años:
27+28+15+4+5
# Out:
# 79

# %%
#Casos favorables: 79
#Casos totales: 440 (total hombres)
round(79/440*100,1)
# Out:
# 18.0

# %% [markdown]
# **Respuesta:** La probabilidad en este caso es de 18%

# %% [markdown]
# ## Actividad 3

# %% [markdown]
# Una empresa de tecnología ha recolectado datos de los tickets ingresados en su sistema de soporte técnico durante el último mes. Cada ticket incluye el tipo de solicitud (Fallo de hardware, Fallo de software, Fallo de red o Requerimiento funcional), la urgencia (Alta, Media o Baja) y el estado (Resuelto o Pendiente).
#
# Importa la **<a href="https://docs.google.com/spreadsheets/d/1x0Zxj-juwv0BXkLIDtKziTNihsL8AVjo/export?format=xlsx
# ">base de datos</a>** y responde las siguientes preguntas:

# %%
import pandas as pd
base_datos = pd.read_excel('Base7_3.xlsx')
base_datos.head(2)
# Out:
#    Tipo de solicitud Urgencia    Estado
# 0       Fallo de red     Baja  Resuelto
# 1  Fallo de software     Baja  Resuelto

# %%
Tabla1 = pd.crosstab( base_datos['Tipo de solicitud'], base_datos['Urgencia'],
                     margins= True)
Tabla1
# Out:
# Urgencia                 Alta  Baja  Media  All
# Tipo de solicitud
# Fallo de hardware           8    10     41   59
# Fallo de red                8    28     60   96
# Fallo de software          15    29     76  120
# Requerimiento funcional     3     8     14   25
# All                        34    75    191  300

# %% [markdown]
# 1. Si se selecciona un ticket al azar, ¿cuál es la probabilidad de que sea una solicitud de tipo Fallo de red?

# %%
#Casos favorables:96
#Casos totales: 300
round(96/300*100,1)
# Out:
# 32.0

# %% [markdown]
# **Respuesta:** La probabilidad es 32%

# %% [markdown]
# 2. ¿Cuál es la probabilidad de que un ticket seleccionado al azar sea del tipo Falla de software y tenga urgencia baja?

# %%
#Casos favorables:29
#casos totales:300
round(29/300*100,1)
# Out:
# 9.7

# %% [markdown]
# **Respuesta:** La probabilidad es 9,7%

# %%
Tabla2 = pd.crosstab( base_datos['Tipo de solicitud'], base_datos['Estado'],
                     margins= True)
Tabla2
# Out:
# Estado                   Pendiente  Resuelto  All
# Tipo de solicitud
# Fallo de hardware               18        41   59
# Fallo de red                    20        76   96
# Fallo de software               29        91  120
# Requerimiento funcional          8        17   25
# All                             75       225  300

# %% [markdown]
# 3. Si se selecciona un ticket al azar, ¿cuál es la probabilidad de que sea de tipo Fallo de hardware o que aún esté pendiente?

# %% [markdown]
# En el caso que aparezca un conector "o", lo que hacemos es sumar el total de ambas categorías y restar por la intersección de ellas.

# %%
#Probabilidad de la unión:
#Cantidad de ticket Fallo de hardware o pendiente:
59+75-18
# Out:
# 116

# %%
#casos favorables: 116
#casos totales: 300
round(116/300*100,1)
# Out:
# 38.7

# %% [markdown]
# **Respuesta:** la probabilidad de escoger un registro de fallo de hardware o pendiente es 38,7%

# %% [markdown]
# 4. ¿Cuál es la probabilidad de que un ticket esté resuelto, dado que es de tipo Fallo de hardware?

# %%
#Probabilidad condicional:
#Casos favorables: 41 (resuelto y fallo de hardware)
#Casos totales: 59 (fallo de hardware)
round(41/59*100,1)
# Out:
# 69.5

# %% [markdown]
# **Respuesta:** La probabilidad en este caso es 69,5%

# %% [markdown]
# 5. Si se selecciona un ticket al azar, ¿cuál es la probabilidad de que sea una solicitud de urgencia alta?

# %%
#Casos favorables:34
#Casos totales:300
round(34/300*100,1)
# Out:
# 11.3

# %% [markdown]
# **Respuesta:** La probabilidad es 11,3%

# %% [markdown]
# 6. ¿Cuál es la probabilidad de que un ticket sea de tipo Fallo de red y esté pendiente?

# %%
#Casos favorables: 20 (fallo de red y pendiente)
#Casos totales: 300
round(20/300*100,1)
# Out:
# 6.7

# %% [markdown]
# **Respuesta:** La probabilidad es 6,7%

# %% [markdown]
# 7. ¿Cuál es la probabilidad de que un ticket tenga urgencia alta, dado que es de tipo Fallo de red?

# %%
#Probabilidad condicional:
#Casos favorables: 34 (urgencia alta y fallo de red)
#Casos totales: 96 (fallo de red)
round(34/96*100,1)
# Out:
# 35.4

# %% [markdown]
# **Respuesta:** La probabilidad en este caso es 35,4%

# %%
Tabla3 = pd.crosstab( base_datos['Estado'], base_datos['Urgencia'],
                     margins= True)
Tabla3
# Out:
# Urgencia   Alta  Baja  Media  All
# Estado
# Pendiente    10    12     53   75
# Resuelto     24    63    138  225
# All          34    75    191  300

# %% [markdown]
# 8. ¿Cuál es la probabilidad de que un ticket esté resuelto, dado que tiene urgencia baja?

# %%
#Probabilidad condicional:
#Casos favorables: 63 (resuelto y baja)
#Casos totales: 75 (urgencia baja)
round(63/75*100,1)
# Out:
# 84.0

# %% [markdown]
# **Respuesta:** La probabilidad en este caso es 84%

# %% [markdown]
# 9. ¿Cuál es la probabilidad de que un ticket sea de tipo Requerimiento funcional o esté resuelto?

# %%
#Probabilidad de la unión:
#Cantidad de registros requerimiento funcional o resuelto:
25+225-17
# Out:
# 233

# %%
#Casos favorables 233
#Casos totales 300
round(233/300*100,1)
# Out:
# 77.7

# %% [markdown]
# **Respuesta:** La probabilidad en este caso es 37,7%

# %% [markdown]
# ## Actividad 4

# %% [markdown]
# Un equipo de administración de redes analizó más de 200 incidentes registrados, clasificando el tipo de falla (Conexión, DNS, Firewall, Latencia), el día de la semana en que ocurrió, y si fue causada por error humano o no.
#
# Importa la **<a href="https://drive.google.com/uc?export=download&id=1MsQUDY51dL6a2s1O4h1i_uucAhliqOIF
# ">base de datos</a>** y responde las siguientes preguntas:

# %% [markdown]
# 1. Según los datos, ¿qué tipo de falla presenta la mayor probabilidad de ocurrencia?

# %% [markdown]
# 2. Un integrante del equipo de redes afirma que es más probable que se presenten incidentes los días viernes, por lo que sugiere asignar más personal ese día. ¿Tiene razón en su afirmación? Justifica tu respuesta.

# %% [markdown]
# 3. Considerando que hay mayor probabilidad de que ocurran fallas los lunes, ¿cuál es la falla más común durante este día de la semana?

# %% [markdown]
# 4. El equipo de redes está evaluando en qué día de la semana suelen producirse más errores humanos para diseñar mejores estrategias de capacitación y prevención. Si se produce un error humano, ¿cuál es el día más probable en que haya ocurrido?

# %% [markdown]
# 5. Se ha detectado que muchas configuraciones incorrectas en los firewalls generan interrupciones de servicio. Para evaluar si este tipo de falla está efectivamente asociado a errores humanos, el equipo decide revisar los registros. Dado que la falla registrada es de tipo Firewall, ¿cuál es la probabilidad de que haya sido causada por error humano?

# %% [markdown]
# 6. El equipo de redes busca identificar momentos críticos en los que ocurren fallas importantes, especialmente aquellas relacionadas con la conexión. ¿Es más probable que una falla ocurra un viernes y sea por Conexión, o que ocurra un sábado y sea por Latencia? Justifica tu respuesta.

# %% [markdown]
# 7. El equipo de redes ha notado que los domingos suelen ser más exigentes, ya que hay menos personal disponible y cualquier error puede generar retrasos importantes. Además, una parte de las fallas registradas se deben a errores humanos, muchas veces por carga o distracción. Para dimensionar este riesgo, quieren saber: ¿Cuál es la probabilidad de que una falla haya sido causada por error humano o que haya ocurrido un domingo?
